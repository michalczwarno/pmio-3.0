# %% [markdown]
# <a href="https://colab.research.google.com/github/michalczwarno/pmio-3.0/blob/master/ACE_intelligence_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# start by linking Google Account that is authenticated to access Google Cloud project

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %% [markdown]
# Let's add better formattitng for the tables

# %%
# %load_ext google.colab.data_table

# %%
# %%bigquery --project delta-smile-276014 headcount
# SELECT * FROM `bronze.hr_gsheet_headcount`

# %%
headcount
# Out:
#                                Email  ...   Hire_date
# 0     gillian.macmannis@docusign.com  ...  2016-02-29
# 1           Chris.Rimer@docusign.com  ...  2018-07-16
# 2            wes.womack@docusign.com  ...  2016-04-04
# 3           Susan.McRae@docusign.com  ...  2015-01-12
# 4         Gabriel.Marra@docusign.com  ...  2020-01-06
# ...                              ...  ...         ...
# 5679                            None  ...        None
# 5680                            None  ...        None
# 5681                            None  ...        None
# 5682                            None  ...        None
# 5683                            None  ...        None
#
# [5684 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
